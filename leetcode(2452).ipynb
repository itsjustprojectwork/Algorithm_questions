# %%
# approach 1

# fail why??->cause we are counting the frequency and avoiding positions of letters
def make_freq(s):
    freq = {}
    for ch in s:
        if ch in freq:
            freq[ch]+=1
        else:
            freq[ch] = 1
    return freq

queries = ["word","note","ants","wood"]
dictionary = ["wood","joke","moat"]
n= len(dictionary)
for s in queries:
    s1 = s #queries
    freq_s1 = make_freq(s1)
    for i in range(n):
        s2 = dictionary[i]#dictionary
        freq_s2 = make_freq(s2)
        edit_char = 0
        for char in freq_s2:
            if char in freq_s1:
                edit_char += abs(freq_s1[char] - freq_s2[char])
            else:
                edit_char+=freq_s2[char]
        print(s2,s1,edit_char)
    print()
# Out:
# wood word 1
# joke word 3
# moat word 3
#
# wood note 3
# joke note 2
# moat note 2
#
# wood ants 4
# joke ants 4
# moat ants 2
#
# wood wood 0
# joke wood 4
# moat wood 4

# %%
# approach 2
queries =["hug","fkl","lpj","yok","khk","zpl","vtc"]
dictionary =["pil","iqa","etk","ytp","lpl","zxb"]
l1= []
n = len(dictionary)
for q in queries:
    s1 = q
    word = ''
    for i in range(n):
        s2 = dictionary[i]
        edit = 0
        s = len(s2)
        for i in range(s):
            if s1[i]!=s2[i]:
                edit+=1
        if edit<=2:
            word = s1
    if word =='':
        continue
    else:
        l1.append(word)
            
l1
# Out:
# ['fkl', 'lpj', 'yok', 'khk', 'zpl', 'vtc']

# %%
k
# Out:
# 3
