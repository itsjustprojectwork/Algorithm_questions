# %% [markdown]
# 175. Combine Two Tables

# %%
import pandas as pd

# %%
# Person table
person = pd.DataFrame({
    'personId': [1, 2],
    'lastName': ['Wang', 'Alice'],
    'firstName': ['Allen', 'Bob']
})

# Address table
address = pd.DataFrame({
    'addressId': [1, 2],
    'personId': [2, 3],
    'city': ['New York City', 'Leetcode'],
    'state': ['New York', 'California']
})

# %%
merged = person.merge(address,
                       left_on = 'personId',
                       right_on = 'personId',
                       how = 'left'
                       )

# %%
merged
# Out:
#    personId lastName firstName  addressId           city     state
# 0         1     Wang     Allen        NaN            NaN       NaN
# 1         2    Alice       Bob        1.0  New York City  New York

# %%
person
# Out:
#    personId lastName firstName
# 0         1     Wang     Allen
# 1         2    Alice       Bob

# %%
address
# Out:
#    addressId  personId           city       state
# 0          1         2  New York City    New York
# 1          2         3       Leetcode  California

# %%
# answer
merged[['firstName','lastName','city','state']]
# Out:
#   firstName lastName           city     state
# 0     Allen     Wang            NaN       NaN
# 1       Bob    Alice  New York City  New York

# %%
result = merged[['firstName','lastName','city','state']]
result
# Out:
#   firstName lastName           city       state
# 0     Allen     Wang  New York City    New York
# 1       Bob    Alice       Leetcode  California
