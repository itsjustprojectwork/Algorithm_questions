# %% [markdown]
# 3718. Smallest Missing Multiple of K
# <br>
# Given an integer array nums and an integer k, return the smallest positive multiple of k that is missing from nums.
# <br>
# A multiple of k is any positive integer divisible by k.
#
#
# <br>
# Example 1:<br>
#
# Input: nums = [8,2,3,4,6], k = 2<br>
# <br>
# Output: 10
# <br>
# Explanation:
# <br>
# The multiples of k = 2 are 2, 4, 6, 8, 10, 12... and the smallest multiple missing from nums is 10.
# <br>
# Example 2:<br>
# <br>
# Input: nums = [1,4,7,10,15], k = 5
# <br>
# Output: 5
# <br>
# Explanation:
# <br>
# The multiples of k = 5 are 5, 10, 15, 20... and the smallest multiple missing from nums is 5.

# %%
nums = [8,4,6,5,2]
k = 2

# %% [markdown]
# below solution works for some test case but not all.need to find another one

# %%
current_sum = 0
n = 1
for num in nums:
    if num % k ==0:
        current_sum+=(num//k)
        n+=1
actual_sum = n*(n+1)//2
multiple  = actual_sum - current_sum
print(k*multiple)
# Out:
# 0

# %%
#brute froce is the best approach for this problem
for i in range(1,len(nums)+2):
    x = k*i
    t = False
    for num in nums:
        if num==x:
            t = True
            break
    if t == False:
        print(x)
        break
# Out:
# 10
