# %% [markdown]
# 279. Perfect Squares
# <br>
# Given an integer n, return the least number of perfect square numbers that sum to n.
# <br>
# A perfect square is an integer that is the square of an integer; in other words, it is the product of some integer with itself. For example, 1, 4, 9, and 16 are perfect squares while 3 and 11 are not.
# <br>
#
#
# Example 1:<br>
# <br>
# Input: n = 12<br>
# Output: 3<br>
# Explanation: 12 = 4 + 4 + 4.<br>
# Example 2:<br>
# <br>
# Input: n = 13<br>
# Output: 2<br>
# Explanation: 13 = 4 + 9<br>

# %%
n = 16
count = 1
nums = []
for i in range(1,n+1):
    if count*count == i:
        nums.append(i)
        count+=1
nums
# Out:
# [1, 4, 9, 16]

# %%
# approach 1 fail its not not working for n=12 its just taking largest square ≤ target.
n = 16
count = 1
nums = []
for i in range(1,n+1):
    if count*count == i:
        nums.append(i)
        count+=1
target = n
count = 0
while target!=0:
    left = 0
    right = len(nums)-1
    min_num = float('-inf')
    while left<=right:
        mid = (left+right)//2
        if nums[mid]<=target:
            val = nums[mid]
            if val>min_num:
                min_num = val
            left = mid + 1
        else:
            right = mid - 1
    target-= min_num
    count+=1
print(count)
# Out:
# 1

# %%
n = 16
ans_arr = [float('inf')] * (n+1)
ans_arr[0] = 0
nums = []
i = 1
while i*i<= n:
    nums.append(i*i)
    i+=1
for i in range(1,n+1):
    min_val = float('inf')
    for num in nums:
       if num<=i:
           val =  1 + ans_arr[i-num]
           if val<min_val:
               min_val = val

    ans_arr[i] = min_val 
    
print(ans_arr[n])
print(ans_arr)
# Out:
# 1
# [0, 1, 2, 3, 1, 2, 3, 4, 2, 1, 2, 3, 3, 2, 3, 4, 1]

# %%
squares = []
k = 16
i = 1
while i*i<=k:
    squares.append(i*i)
    i+=1

squares
# Out:
# [1, 4, 9, 16]
