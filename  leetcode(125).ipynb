# %%
print('leetcode 125')
# Out:
# leetcode 125

# %%
import string
s = "A man, a plan, a canal: Panama"

# %%
ispalin = True
S = ''
for ch in s:
    if ch == ' ':
        continue
    if ch in string.punctuation:
        ch = ''
    else:
        c = ch.lower()
        S+=c
if S[::-1] == S:
    print('true')
else:
    print('false')
# Out:
# true

# %%
is
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ispalin
#
# NameError: name 'ispalin' is not defined
